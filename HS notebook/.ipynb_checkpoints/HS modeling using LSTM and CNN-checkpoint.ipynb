# %% [markdown]
# <h1><center>Predicting significant wave height using machine learning</center></h1>

# %% [markdown]
# <img src="https://www.pacioos.hawaii.edu/wp-content/uploads/2018/05/news-kalaeloa-barbers-point-wave-buoy-672x350.jpg" alt="Wave buoy image" title="" />

# %% [markdown]
# This notebook present code example to model signficant wave height using **two machine learning models**:
# 1. LSTM model
# 2. CNN model
#
# We used the data of the buoy station number <font color=blue>6400045</font>, downloaded from the European marine observation and data network website ("https://www.emodnet-physics.eu/Map/DefaultMap.aspx")
#
#
# You will need to install the common data manipulation library **(pandas, NumPy)**, **Keras** for the machine learning part, and **Altair** for data visualization

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import altair as alt
from vega_datasets import data
alt.data_transformers.enable('json')

import datetime

# %%
#load the data
rawdata = pd.read_excel("All_data_6400045.xlsx", header=0, index_col=0)
rawdata
# Out:
#                          DEPTH   ATMS  ATMS_QC DEWT  DEWT_QC DRYT  DRYT_QC  \
# TIME
# 01/01/2015 00:00:00:000      0  996.1        1  3.5        1  8.1        1
# 01/01/2015 01:00:00:000      0  997.3        1  4.7        1  8.2        1
# 01/01/2015 02:00:00:000      0  998.5        1  2.2        1  7.9        1
# 01/01/2015 03:00:00:000      0  999.3        1  3.7        1  7.9        1
# 01/01/2015 04:00:00:000      0  999.5        1  0.6        1    8        1
# ...                        ...    ...      ...  ...      ...  ...      ...
# 31/10/2020 19:00:00:000      0    978        1   --        9  8.6        1
# 31/10/2020 20:00:00:000      0  979.6        1   --        9    8        1
# 31/10/2020 21:00:00:000      0  980.6        1   --        9  8.3        1
# 31/10/2020 22:00:00:000      0  980.8        1   --        9  8.7        1
# 31/10/2020 23:00:00:000      0     --        9   --        9   --        9
#
#                           LATITUDE  LONGITUDE  POSITION_QC  ... TEMP_QC  \
# TIME                                                        ...
# 01/01/2015 00:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 01:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 02:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 03:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 04:00:00:000  59.099998    -11.401            1  ...    -127
# ...                            ...        ...          ...  ...     ...
# 31/10/2020 19:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 20:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 21:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 22:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 23:00:00:000  59.099998    -11.401            1  ...    -127
#
#                          TIME_QC  VHM0 VHM0_QC  VTZA VTZA_QC  WDIR WDIR_QC  \
# TIME
# 01/01/2015 00:00:00:000        1   4.9       1     8       1    --       9
# 01/01/2015 01:00:00:000        1   5.8       1     8       1    --       9
# 01/01/2015 02:00:00:000        1     6       1     8       1    --       9
# 01/01/2015 03:00:00:000        1   5.8       1     8       1    --       9
# 01/01/2015 04:00:00:000        1   5.8       1     8       1    --       9
# ...                          ...   ...     ...   ...     ...   ...     ...
# 31/10/2020 19:00:00:000        1   4.9       1     8       1   290       1
# 31/10/2020 20:00:00:000        1   4.5       1     8       1   270       1
# 31/10/2020 21:00:00:000        1   4.2       1     7       1   270       1
# 31/10/2020 22:00:00:000        1   4.4       1     7       1   260       1
# 31/10/2020 23:00:00:000        1    --       9    --       9    --       9
#
#                          WSPD WSPD_QC
# TIME
# 01/01/2015 00:00:00:000    --       9
# 01/01/2015 01:00:00:000    --       9
# 01/01/2015 02:00:00:000    --       9
# 01/01/2015 03:00:00:000    --       9
# 01/01/2015 04:00:00:000    --       9
# ...                       ...     ...
# 31/10/2020 19:00:00:000    16       1
# 31/10/2020 20:00:00:000  12.4       1
# 31/10/2020 21:00:00:000  12.9       1
# 31/10/2020 22:00:00:000  10.8       1
# 31/10/2020 23:00:00:000    --       9
#
# [51144 rows x 21 columns]

# %% [markdown]
# <h2>In this example, we are just gonna use wind speed and wind direction as input to the model</h2>

# %%
data = rawdata[["VHM0", "WDIR", "WSPD"]]
data
# Out:
#                         VHM0 WDIR  WSPD
# TIME
# 01/01/2015 00:00:00:000  4.9   --    --
# 01/01/2015 01:00:00:000  5.8   --    --
# 01/01/2015 02:00:00:000    6   --    --
# 01/01/2015 03:00:00:000  5.8   --    --
# 01/01/2015 04:00:00:000  5.8   --    --
# ...                      ...  ...   ...
# 31/10/2020 19:00:00:000  4.9  290    16
# 31/10/2020 20:00:00:000  4.5  270  12.4
# 31/10/2020 21:00:00:000  4.2  270  12.9
# 31/10/2020 22:00:00:000  4.4  260  10.8
# 31/10/2020 23:00:00:000   --   --    --
#
# [51144 rows x 3 columns]

# %%
#We need to convert the type of the data from None to numeric and replace the "--" characters with Nan values
for col in data.columns:
    data[col] = pd.to_numeric(data[col], errors='coerce')
# Out:
# <ipython-input-4-67e2378ca6f9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data
# Out:
#                          VHM0   WDIR  WSPD
# TIME
# 01/01/2015 00:00:00:000   4.9    NaN   NaN
# 01/01/2015 01:00:00:000   5.8    NaN   NaN
# 01/01/2015 02:00:00:000   6.0    NaN   NaN
# 01/01/2015 03:00:00:000   5.8    NaN   NaN
# 01/01/2015 04:00:00:000   5.8    NaN   NaN
# ...                       ...    ...   ...
# 31/10/2020 19:00:00:000   4.9  290.0  16.0
# 31/10/2020 20:00:00:000   4.5  270.0  12.4
# 31/10/2020 21:00:00:000   4.2  270.0  12.9
# 31/10/2020 22:00:00:000   4.4  260.0  10.8
# 31/10/2020 23:00:00:000   NaN    NaN   NaN
#
# [51144 rows x 3 columns]

# %% [markdown]
# # Data visualization using Altair

# %% [markdown]
# We are gonna create a date column to plot the data it using the Altair visualization library

# %%
time = list(data.index.values)
for i in range(len(time)):
    time[i] = datetime.datetime.strptime(time[i][:19], '%d/%m/%Y %H:%M:%S')

# %%
data["Date"] = time
# Out:
# <ipython-input-7-792733578a69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date"] = time

# %%
alt.Chart(data, title="Evolution of significant wave height over time").mark_line(point=True).encode(
    x='Date',
    y='VHM0',
    tooltip='Date'
).properties(
    width=1000,
    height=400
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
    alt.X("VHM0", bin=True),
    y='count()',
).properties(
    width=500,
    height=400
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data, title="Evolution of Wind speed over time").mark_line(point=True).encode(
    x='Date',
    y='WSPD',
    tooltip='Date'
).properties(
    width=1000,
    height=400
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h2>We can observe that there's an extreme max value on <font color=blue>march 13th 2008</font> </h2>

# %%
data.loc[data[data["WSPD"] >30].index, "WSPD"] = np.nan
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
#verification that the observation was deleted
data.loc[data[data["WSPD"] >30].index, "WSPD"]
# Out:
# Series([], Name: WSPD, dtype: float64)

# %%
#We can see that the observations was deleted
alt.Chart(data, title="Evolution of wind speed over time").mark_line(point=True).encode(
    x='Date',
    y='WSPD',
    tooltip='Date'
).properties(
    width=1000,
    height=400
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h2> Data preparation</h2>

# %%
#We are gonna drop date because we don't need it now
data = data.drop("Date",axis=1)
data
# Out:
#                          VHM0   WDIR  WSPD
# TIME
# 01/01/2015 00:00:00:000   4.9    NaN   NaN
# 01/01/2015 01:00:00:000   5.8    NaN   NaN
# 01/01/2015 02:00:00:000   6.0    NaN   NaN
# 01/01/2015 03:00:00:000   5.8    NaN   NaN
# 01/01/2015 04:00:00:000   5.8    NaN   NaN
# ...                       ...    ...   ...
# 31/10/2020 19:00:00:000   4.9  290.0  16.0
# 31/10/2020 20:00:00:000   4.5  270.0  12.4
# 31/10/2020 21:00:00:000   4.2  270.0  12.9
# 31/10/2020 22:00:00:000   4.4  260.0  10.8
# 31/10/2020 23:00:00:000   NaN    NaN   NaN
#
# [51144 rows x 3 columns]

# %%
#Scale the data using minmax scaling
scaler = MinMaxScaler(feature_range=(0,1))
data = data.to_numpy()
data = scaler.fit_transform(data)
data = pd.DataFrame(data, columns=["VHM0","WDIR","WSPD"])
data
# Out:
#            VHM0      WDIR      WSPD
# 0      0.283133       NaN       NaN
# 1      0.337349       NaN       NaN
# 2      0.349398       NaN       NaN
# 3      0.337349       NaN       NaN
# 4      0.337349       NaN       NaN
# ...         ...       ...       ...
# 51139  0.283133  0.800000  0.589354
# 51140  0.259036  0.742857  0.452471
# 51141  0.240964  0.742857  0.471483
# 51142  0.253012  0.714286  0.391635
# 51143       NaN       NaN       NaN
#
# [51144 rows x 3 columns]

# %% [markdown]
# <h2>In our model, we are gonna use the previous values of significant wave height measured to predict the next value</h2>

# %%
#So we are gonna shift the column to add the previous values to the model
data["VHM0 t-1"] = data["VHM0"].shift()
data
# Out:
#            VHM0      WDIR      WSPD  VHM0 t-1
# 0      0.283133       NaN       NaN       NaN
# 1      0.337349       NaN       NaN  0.283133
# 2      0.349398       NaN       NaN  0.337349
# 3      0.337349       NaN       NaN  0.349398
# 4      0.337349       NaN       NaN  0.337349
# ...         ...       ...       ...       ...
# 51139  0.283133  0.800000  0.589354  0.265060
# 51140  0.259036  0.742857  0.452471  0.283133
# 51141  0.240964  0.742857  0.471483  0.259036
# 51142  0.253012  0.714286  0.391635  0.240964
# 51143       NaN       NaN       NaN  0.253012
#
# [51144 rows x 4 columns]

# %% [markdown]
# <h3>The input of the LSTM model must be three dimensionnal, reprsenting respectively:</h3>
#
# 1. the Samples
# 2. the time steps
# 3. Features
#
# <h3>The next function is used to prepare and reshape data to be used in the LSTM model.</h3>

# %%
def data_prep(data, lag, X_col, y_col):
    #data---type: numpy 2d array -----def: is the data used
    #lag---type: int-------def:  represent the the time steps 
    #X_col----type: list,--------def: represente the index of the columns used as input in the model
    #y_col----type: list,--------def: represente the index of the columns used as output in the model
    X_train = []
    y_train = []
    for i in range(lag, int(len(data))):
        X_train.append(data[i-lag:i, X_col])
        y_train.append(data[i-1, y_col])
    X_train, y_train = np.array(X_train), np.array(y_train)

    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], len(X_col)))
    return [X_train, y_train]

# %%
#the time step used is 10 previous hours of data measured
X, y = data_prep(data.to_numpy(), lag=10, X_col=[1,2,3], y_col=[0])

# %%
#Data verification
X[:10]
# Out:
# array([[[       nan,        nan,        nan],
#         [       nan,        nan, 0.28313253],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ]],
#
#        [[       nan,        nan, 0.28313253],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892]],
#
#        [[       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.29518072]],
#
#        [[       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.27710843]],
#
#        [[       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.27710843],
#         [       nan,        nan, 0.27710843]]])

# %%
#We need to reshape the y array
y = y.reshape(len(y),)
#Data verification
y[:10]
# Out:
# array([0.31325301, 0.30722892, 0.31325301, 0.30722892, 0.31325301,
#        0.29518072, 0.29518072, 0.27710843, 0.27710843, 0.24096386])

# %%
#Data verification
data.head(15)
# Out:
#         VHM0  WDIR  WSPD  VHM0 t-1
# 0   0.283133   NaN   NaN       NaN
# 1   0.337349   NaN   NaN  0.283133
# 2   0.349398   NaN   NaN  0.337349
# 3   0.337349   NaN   NaN  0.349398
# 4   0.337349   NaN   NaN  0.337349
# 5   0.337349   NaN   NaN  0.337349
# 6   0.337349   NaN   NaN  0.337349
# 7   0.313253   NaN   NaN  0.337349
# 8   0.325301   NaN   NaN  0.313253
# 9   0.313253   NaN   NaN  0.325301
# 10  0.307229   NaN   NaN  0.313253
# 11  0.313253   NaN   NaN  0.307229
# 12  0.307229   NaN   NaN  0.313253
# 13  0.313253   NaN   NaN  0.307229
# 14  0.295181   NaN   NaN  0.313253

# %%
#we need to get the corresponding time to plot it in Altair in the next sections
time_model = np.array(time[10:])

# %% [markdown]
# <h3>The Next cell present how to find and delete the nan values in the input and output numpy arrays</h3>

# %%
#Determine where there's a nan value in input or output (if any of [x1, x2, ...] == nan np.isnan == True)
x_nan_index = np.isnan(X).any(axis=1)
x_nan_index = x_nan_index[:,0] | x_nan_index[:,1] |  x_nan_index[:,2]
y_nan_index = np.isnan(y)
#Apply the OR operation on the two index
train_index = x_nan_index | y_nan_index
#Get the values or vectors where's there's no nan values
X = X[~train_index]
y = y[~train_index]
time_model = time_model[~train_index]

# %%
#Now we split the data into train and test datasets, and also split the time array
X_train, X_test, y_train, y_test, time_train, time_test = train_test_split(X, y, time_model, test_size=0.33, random_state=77)

# %% [markdown]
# <h1><center>Modeliing using LSTM</center></h1>

# %% [markdown]
# <img src="https://miro.medium.com/max/594/0*dhz-SOm-BW3rTEYa" alt="LSTM model image" title="" />

# %% [markdown]
# <h3> <center>In the next cells, we are gonna create and train out LSTM model and check its performance</center></h3>
# <h4> We would like to point out that the architecture of the model is not optimized, and there's overfitting that can be avoided by analyzing more efficiently the data and maybe split the train, validation, and test datasets manually</h4>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import tensorflow as tf

# %%
#Define the structure of the model
model = Sequential()

model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 3)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 100))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')


history = model.fit(X_train, y_train, epochs =100, batch_size = 1000, validation_split=0.3)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 3s 198ms/step - loss: 0.0194 - val_loss: 0.0082
# Epoch 2/100
# 14/14 [==============================] - 2s 113ms/step - loss: 0.0066 - val_loss: 0.0038
# Epoch 3/100
# 14/14 [==============================] - 2s 127ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 4/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 5/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 6/100
# 14/14 [==============================] - 2s 123ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 7/100
# 14/14 [==============================] - 2s 120ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 8/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 9/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 10/100
# 14/14 [==============================] - 2s 126ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 11/100
# 14/14 [==============================] - 2s 132ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 12/100
# 14/14 [==============================] - 2s 123ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 13/100
# 14/14 [==============================] - 2s 130ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 14/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 15/100
# 14/14 [==============================] - 2s 115ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 16/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 17/100
# 14/14 [==============================] - 2s 121ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 18/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch
#checking the performance of the model on the training period
preds = model.predict(X_train)
rmse = np.sqrt(mean_squared_error(y_train, preds))
r2 = r2_score(y_train, preds)
print('results for calibration \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for calibration
#
# RMSE: 0.021070
# R²: 0.962008

# %%
#checking the performance of the model on the testing period
preds_test = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds_test))
r2 = r2_score(y_test, preds_test)
print('results for testing \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for testing
#
# RMSE: 0.020307
# R²: 0.964279

# %% [markdown]
# <h3> We can see that the model have a great performance</h3>

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# <h2><center> Training Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the training period
train_to_plot = pd.DataFrame({"y_true": y_train,
                 "y_pred" : preds.reshape(len(preds)),
                 "date" : time_train})
train_to_plot
# Out:
#          y_true    y_pred                date
# 0      0.162651  0.178646 2019-10-12 10:00:00
# 1      0.126506  0.138765 2019-09-20 06:00:00
# 2      0.054217  0.061174 2019-07-20 04:00:00
# 3      0.084337  0.082843 2017-08-15 00:00:00
# 4      0.096386  0.102383 2017-09-21 16:00:00
# ...         ...       ...                 ...
# 19867  0.042169  0.044813 2019-07-12 02:00:00
# 19868  0.054217  0.054456 2020-06-18 12:00:00
# 19869  0.090361  0.096563 2020-08-28 19:00:00
# 19870  0.403614  0.415496 2018-01-03 20:00:00
# 19871  0.240964  0.236097 2019-01-14 15:00:00
#
# [19872 rows x 3 columns]

# %%
#Q-Q plot of the training period
alt.Chart(train_to_plot, title="Q-Q plot of the LSTM model (training period)").mark_point().encode(
    x='y_true',
    y='y_pred',
    tooltip='date'
).properties(
    width=400,
    height=400
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h3>We can observe that some values were not predicted very well, we recommend the potential users to check the data</h3>

# %%
#Plotting the evolution of predicted and observed values over time for the traiing period
alt.Chart(pd.melt(train_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), title="Evolution of the predicted and the observed values(training period)"
         ).mark_circle().encode(
    x='date',
    y='value',
    color='categorie',
    tooltip='date'
).properties(
    width=1200,
    height=400
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h2><center> Testing Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the testing period
test_to_plot = pd.DataFrame({"y_true": y_test,
                 "y_pred" : preds_test.reshape(len(preds_test)),
                 "date" : time_test})
test_to_plot
# Out:
#         y_true    y_pred                date
# 0     0.126506  0.123649 2020-05-29 17:00:00
# 1     0.180723  0.178688 2019-04-29 14:00:00
# 2     0.228916  0.254961 2016-11-09 12:00:00
# 3     0.156627  0.181433 2018-05-13 11:00:00
# 4     0.198795  0.225382 2019-01-31 01:00:00
# ...        ...       ...                 ...
# 9783  0.090361  0.080048 2020-05-31 07:00:00
# 9784  0.162651  0.159925 2019-10-19 20:00:00
# 9785  0.198795  0.225685 2016-09-21 06:00:00
# 9786  0.222892  0.231940 2018-12-17 12:00:00
# 9787  0.072289  0.075942 2016-05-23 17:00:00
#
# [9788 rows x 3 columns]

# %%
#Q-Q plot of the testing period
alt.Chart(test_to_plot, title="Q-Q plot of the LSTM model (testing period)").mark_point().encode(
    x='y_true',
    y='y_pred',
    tooltip='date'
).properties(
    width=400,
    height=400
)
# Out:
# alt.Chart(...)

# %%
#Plotting the evolution of predicted and observed values over time for the traiing period
alt.Chart(pd.melt(test_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), title="Evolution of the predicted and the observed values(testing period)"
         ).mark_circle().encode(
    x='date',
    y='value',
    color='categorie',
    tooltip='date'
).properties(
    width=1200,
    height=400
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h1><center>Modeliing using CNN</center></h1>

# %% [markdown]
# <img src="https://www.aimspress.com/aimspress-data/mbe/2021/1/PIC/mbe-18-01-022-g004.jpg" alt="CNN for time series image" title="" />

# %% [markdown]
# <h3> <center>In the next cells, we are gonna create and train our CNN model and check its performance</center></h3>
# <h4> We would like to point out that the architecture of the model is not optimized, and there's overfitting that can be avoided by analyzing more efficiently the data and maybe split the train, validation, and test datasets manually</h4>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import tensorflow as tf

# %%
#Define the structure of the model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation=tf.keras.layers.LeakyReLU(alpha=0.3), input_shape=(X_test.shape[1], 3)))
model.add(MaxPooling1D(pool_size=2, padding='SAME'))

model.add(Flatten())

model.add(Dense(100, activation='elu'))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

history = model.fit(X_train, y_train, epochs = 150, batch_size = 1000, validation_split=0.3)
# Out:
# Epoch 1/150
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0189 - val_loss: 0.0060
# Epoch 2/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0017
# Epoch 3/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 4/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0010
# Epoch 5/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 9.4692e-04
# Epoch 6/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 8.6887e-04
# Epoch 7/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 8.1157e-04
# Epoch 8/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 7.5416e-04
# Epoch 9/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 7.1854e-04
# Epoch 10/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 6.9790e-04
# Epoch 11/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 6.5348e-04
# Epoch 12/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 6.3825e-04
# Epoch 13/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 6.1546e-04
# Epoch 14/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 6.0649e-04
# Epoch 15/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 5.8650e-04
# Epoch 16/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 5.6775e-04
# Epoch 17/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 5.5766e-04
# Epoch 18/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 5.5109e-04
# Epoch 19/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 5.4994e-04
# Epoch 20/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 5.3550e-04
# Epoch 21/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.
150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2537e-04 - val_loss: 3.8941e-04
# Epoch 121/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3650e-04 - val_loss: 3.9104e-04
# Epoch 122/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5455e-04 - val_loss: 3.9615e-04
# Epoch 123/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4888e-04 - val_loss: 3.8719e-04
# Epoch 124/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3730e-04 - val_loss: 3.8631e-04
# Epoch 125/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2433e-04 - val_loss: 3.9139e-04
# Epoch 126/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4286e-04 - val_loss: 4.1073e-04
# Epoch 127/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2925e-04 - val_loss: 3.9815e-04
# Epoch 128/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2134e-04 - val_loss: 3.9499e-04
# Epoch 129/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4246e-04 - val_loss: 4.2232e-04
# Epoch 130/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4722e-04 - val_loss: 4.0940e-04
# Epoch 131/150
# 14/14 [==============================] - 0s 6ms/step - loss: 5.2569e-04 - val_loss: 4.0377e-04
# Epoch 132/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1001e-04 - val_loss: 3.9241e-04
# Epoch 133/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2360e-04 - val_loss: 4.1855e-04
# Epoch 134/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2717e-04 - val_loss: 4.0076e-04
# Epoch 135/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2308e-04 - val_loss: 3.9556e-04
# Epoch 136/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1445e-04 - val_loss: 3.8733e-04
# Epoch 137/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.9951e-04 - val_loss: 3.8935e-04
# Epoch 138/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.9998e-04 - val_loss: 4.0021e-04
# Epoch 139/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0918e-04 - val_loss: 3.8320e-04
# Epoch 140/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2168e-04 - val_loss: 3.8268e-04
# Epoch 141/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1867e-04 - val_loss: 3.9580e-04
# Epoch 142/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1368e-04 - val_loss: 3.8288e-04
# Epoch 143/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0581e-04 - val_loss: 3.8779e-04
# Epoch 144/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1950e-04 - val_loss: 3.8775e-04
# Epoch 145/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1507e-04 - val_loss: 3.8951e-04
# Epoch 146/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0952e-04 - val_loss: 3.8566e-04
# Epoch 147/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1576e-04 - val_loss: 3.8526e-04
# Epoch 148/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1376e-04 - val_loss: 3.8603e-04
# Epoch 149/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1276e-04 - val_loss: 3.8353e-04
# Epoch 150/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.9974e-04 - val_loss: 3.8489e-04

# %%
#checking the performance of the model on the training period
preds = model.predict(X_train)
rmse = np.sqrt(mean_squared_error(y_train, preds))
r2 = r2_score(y_train, preds)
print('results for calibration \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for calibration
#
# RMSE: 0.020141
# R²: 0.965284

# %%
#checking the performance of the model on the testing period
preds_test = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds_test))
r2 = r2_score(y_test, preds_test)
print('results for testing \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for testing
#
# RMSE: 0.019525
# R²: 0.966976

# %% [markdown]
# <h3> We can see that the model have a great performance</h3>
# <h3>We recommend the potential users to use the CNN instead of LSTM if the performance is the same due to the less computation time</h3>

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# <h2><center> Training Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the training period
train_to_plot = pd.DataFrame({"y_true": y_train,
                 "y_pred" : preds.reshape(len(preds)),
                 "date" : time_train})
train_to_plot
# Out:
#          y_true    y_pred                date
# 0      0.162651  0.173355 2019-10-12 10:00:00
# 1      0.126506  0.139977 2019-09-20 06:00:00
# 2      0.054217  0.049704 2019-07-20 04:00:00
# 3      0.084337  0.088406 2017-08-15 00:00:00
# 4      0.096386  0.097863 2017-09-21 16:00:00
# ...         ...       ...                 ...
# 19867  0.042169  0.046604 2019-07-12 02:00:00
# 19868  0.054217  0.042485 2020-06-18 12:00:00
# 19869  0.090361  0.094711 2020-08-28 19:00:00
# 19870  0.403614  0.412753 2018-01-03 20:00:00
# 19871  0.240964  0.215188 2019-01-14 15:00:00
#
# [19872 rows x 3 columns]

# %%
#Q-Q plot of the training period
alt.Chart(train_to_plot, title="Q-Q plot of the CNN model (training period)").mark_point().encode(
    x='y_true',
    y='y_pred',
    tooltip='date'
).properties(
    width=400,
    height=400
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h3> We can observe that there are also (maybe the same observations as in the LSTM section) some values that were not predicted very well, we recommend the potential users to check the data</h3>

# %%
#Plotting the evolution of predicted and observed values over time for the training period
alt.Chart(pd.melt(train_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), title="Evolution of the predicted and the observed values(training period)"
         ).mark_circle().encode(
    x='date',
    y='value',
    color='categorie',
    tooltip='date'
).properties(
    width=1200,
    height=400
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h2><center> Testing Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the testing period
test_to_plot = pd.DataFrame({"y_true": y_test,
                 "y_pred" : preds_test.reshape(len(preds_test)),
                 "date" : time_test})
test_to_plot
# Out:
#         y_true    y_pred                date
# 0     0.126506  0.119422 2020-05-29 17:00:00
# 1     0.180723  0.169543 2019-04-29 14:00:00
# 2     0.228916  0.255725 2016-11-09 12:00:00
# 3     0.156627  0.168624 2018-05-13 11:00:00
# 4     0.198795  0.210592 2019-01-31 01:00:00
# ...        ...       ...                 ...
# 9783  0.090361  0.093175 2020-05-31 07:00:00
# 9784  0.162651  0.157271 2019-10-19 20:00:00
# 9785  0.198795  0.214351 2016-09-21 06:00:00
# 9786  0.222892  0.235904 2018-12-17 12:00:00
# 9787  0.072289  0.070859 2016-05-23 17:00:00
#
# [9788 rows x 3 columns]

# %%
#Q-Q plot of the testing period
alt.Chart(test_to_plot, title="Q-Q plot of the CNN model (training period)").mark_point().encode(
    x='y_true',
    y='y_pred',
    tooltip='date'
).properties(
    width=400,
    height=400
)
# Out:
# alt.Chart(...)

# %%
#Plotting the evolution of predicted and observed values over time for the training period
alt.Chart(pd.melt(test_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), title="Evolution of the predicted and the observed values(training period)"
         ).mark_circle().encode(
    x='date',
    y='value',
    color='categorie',
    tooltip='date'
).properties(
    width=1200,
    height=400
)
# Out:
# alt.Chart(...)
