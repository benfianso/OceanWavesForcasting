# %% [markdown]
# <h1><center>Predicting significant wave height using machine learning</center></h1>

# %% [markdown]
# <img src="https://www.pacioos.hawaii.edu/wp-content/uploads/2018/05/news-kalaeloa-barbers-point-wave-buoy-672x350.jpg" alt="Wave buoy image" title="" />

# %% [markdown]
# This notebook present code example to model signficant wave height using **two machine learning models**:
# 1. LSTM model
# 2. CNN model
#
# We used the data of the buoy station number <font color=blue>6400045</font>, downloaded from the European marine observation and data network website ("https://www.emodnet-physics.eu/Map/DefaultMap.aspx")
#
#
# You will need to install the common data manipulation library **(pandas, NumPy)**, **Keras** for the machine learning part, and **Pandas viz** for data visualization

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import seaborn as sns

import datetime

# %%
#load the data
rawdata = pd.read_excel("All_data_6400045.xlsx", header=0, index_col=0)
rawdata
# Out:
#                          DEPTH   ATMS  ATMS_QC DEWT  DEWT_QC DRYT  DRYT_QC  \
# TIME
# 01/01/2015 00:00:00:000      0  996.1        1  3.5        1  8.1        1
# 01/01/2015 01:00:00:000      0  997.3        1  4.7        1  8.2        1
# 01/01/2015 02:00:00:000      0  998.5        1  2.2        1  7.9        1
# 01/01/2015 03:00:00:000      0  999.3        1  3.7        1  7.9        1
# 01/01/2015 04:00:00:000      0  999.5        1  0.6        1    8        1
# ...                        ...    ...      ...  ...      ...  ...      ...
# 31/10/2020 19:00:00:000      0    978        1   --        9  8.6        1
# 31/10/2020 20:00:00:000      0  979.6        1   --        9    8        1
# 31/10/2020 21:00:00:000      0  980.6        1   --        9  8.3        1
# 31/10/2020 22:00:00:000      0  980.8        1   --        9  8.7        1
# 31/10/2020 23:00:00:000      0     --        9   --        9   --        9
#
#                           LATITUDE  LONGITUDE  POSITION_QC  ... TEMP_QC  \
# TIME                                                        ...
# 01/01/2015 00:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 01:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 02:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 03:00:00:000  59.099998    -11.401            1  ...    -127
# 01/01/2015 04:00:00:000  59.099998    -11.401            1  ...    -127
# ...                            ...        ...          ...  ...     ...
# 31/10/2020 19:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 20:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 21:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 22:00:00:000  59.099998    -11.401            1  ...    -127
# 31/10/2020 23:00:00:000  59.099998    -11.401            1  ...    -127
#
#                          TIME_QC  VHM0 VHM0_QC  VTZA VTZA_QC  WDIR WDIR_QC  \
# TIME
# 01/01/2015 00:00:00:000        1   4.9       1     8       1    --       9
# 01/01/2015 01:00:00:000        1   5.8       1     8       1    --       9
# 01/01/2015 02:00:00:000        1     6       1     8       1    --       9
# 01/01/2015 03:00:00:000        1   5.8       1     8       1    --       9
# 01/01/2015 04:00:00:000        1   5.8       1     8       1    --       9
# ...                          ...   ...     ...   ...     ...   ...     ...
# 31/10/2020 19:00:00:000        1   4.9       1     8       1   290       1
# 31/10/2020 20:00:00:000        1   4.5       1     8       1   270       1
# 31/10/2020 21:00:00:000        1   4.2       1     7       1   270       1
# 31/10/2020 22:00:00:000        1   4.4       1     7       1   260       1
# 31/10/2020 23:00:00:000        1    --       9    --       9    --       9
#
#                          WSPD WSPD_QC
# TIME
# 01/01/2015 00:00:00:000    --       9
# 01/01/2015 01:00:00:000    --       9
# 01/01/2015 02:00:00:000    --       9
# 01/01/2015 03:00:00:000    --       9
# 01/01/2015 04:00:00:000    --       9
# ...                       ...     ...
# 31/10/2020 19:00:00:000    16       1
# 31/10/2020 20:00:00:000  12.4       1
# 31/10/2020 21:00:00:000  12.9       1
# 31/10/2020 22:00:00:000  10.8       1
# 31/10/2020 23:00:00:000    --       9
#
# [51144 rows x 21 columns]

# %% [markdown]
# <h2>In this example, we are just gonna use wind speed and wind direction as input to the model</h2>

# %%
data = rawdata[["VHM0", "WDIR", "WSPD"]]
data
# Out:
#                         VHM0 WDIR  WSPD
# TIME
# 01/01/2015 00:00:00:000  4.9   --    --
# 01/01/2015 01:00:00:000  5.8   --    --
# 01/01/2015 02:00:00:000    6   --    --
# 01/01/2015 03:00:00:000  5.8   --    --
# 01/01/2015 04:00:00:000  5.8   --    --
# ...                      ...  ...   ...
# 31/10/2020 19:00:00:000  4.9  290    16
# 31/10/2020 20:00:00:000  4.5  270  12.4
# 31/10/2020 21:00:00:000  4.2  270  12.9
# 31/10/2020 22:00:00:000  4.4  260  10.8
# 31/10/2020 23:00:00:000   --   --    --
#
# [51144 rows x 3 columns]

# %%
#We need to convert the type of the data from None to numeric and replace the "--" characters with Nan values
for col in data.columns:
    data[col] = pd.to_numeric(data[col], errors='coerce')
# Out:
# <ipython-input-4-67e2378ca6f9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data
# Out:
#                          VHM0   WDIR  WSPD
# TIME
# 01/01/2015 00:00:00:000   4.9    NaN   NaN
# 01/01/2015 01:00:00:000   5.8    NaN   NaN
# 01/01/2015 02:00:00:000   6.0    NaN   NaN
# 01/01/2015 03:00:00:000   5.8    NaN   NaN
# 01/01/2015 04:00:00:000   5.8    NaN   NaN
# ...                       ...    ...   ...
# 31/10/2020 19:00:00:000   4.9  290.0  16.0
# 31/10/2020 20:00:00:000   4.5  270.0  12.4
# 31/10/2020 21:00:00:000   4.2  270.0  12.9
# 31/10/2020 22:00:00:000   4.4  260.0  10.8
# 31/10/2020 23:00:00:000   NaN    NaN   NaN
#
# [51144 rows x 3 columns]

# %% [markdown]
# # Data visualization

# %% [markdown]
# We are gonna create a date column to plot the data it using the Pandas visualization methods

# %%
time = list(data.index.values)
for i in range(len(time)):
    time[i] = datetime.datetime.strptime(time[i][:19], '%d/%m/%Y %H:%M:%S')

# %%
data["Date"] = time
# Out:
# <ipython-input-7-792733578a69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date"] = time

# %%
sns.set_theme(style="darkgrid")
data.plot(x="Date", y="VHM0", figsize=(18,6))
plt.title('Evolution of significant wave height over time')
# Out:
# Text(0.5, 1.0, 'Evolution of significant wave height over time')

# %%
data["VHM0"].hist(figsize=(8,8))
# Out:
# <AxesSubplot:>

# %%
data.plot(x="Date", y="WSPD", figsize=(18,6))
plt.title('Evolution of wind speed over time')
# Out:
# Text(0.5, 1.0, 'Evolution of wind speed over time')

# %% [markdown]
# <h2>We can observe that there's an extreme max value on <font color=blue>march 13th 2008</font> </h2>

# %%
data.loc[data[data["WSPD"] >30].index, "WSPD"] = np.nan
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
#verification that the observation was deleted
data.loc[data[data["WSPD"] >30].index, "WSPD"]
# Out:
# Series([], Name: WSPD, dtype: float64)

# %%
#We can see that the observations was deleted
data.plot(x="Date", y="WSPD", figsize=(18,6))
plt.title('Evolution of wind speed over time')
# Out:
# Text(0.5, 1.0, 'Evolution of wind speed over time')

# %% [markdown]
# <h2> Data preparation</h2>

# %%
#We are gonna drop date because we don't need it now
data = data.drop("Date",axis=1)
data
# Out:
#                          VHM0   WDIR  WSPD
# TIME
# 01/01/2015 00:00:00:000   4.9    NaN   NaN
# 01/01/2015 01:00:00:000   5.8    NaN   NaN
# 01/01/2015 02:00:00:000   6.0    NaN   NaN
# 01/01/2015 03:00:00:000   5.8    NaN   NaN
# 01/01/2015 04:00:00:000   5.8    NaN   NaN
# ...                       ...    ...   ...
# 31/10/2020 19:00:00:000   4.9  290.0  16.0
# 31/10/2020 20:00:00:000   4.5  270.0  12.4
# 31/10/2020 21:00:00:000   4.2  270.0  12.9
# 31/10/2020 22:00:00:000   4.4  260.0  10.8
# 31/10/2020 23:00:00:000   NaN    NaN   NaN
#
# [51144 rows x 3 columns]

# %%
#Scale the data using minmax scaling
scaler = MinMaxScaler(feature_range=(0,1))
data = data.to_numpy()
data = scaler.fit_transform(data)
data = pd.DataFrame(data, columns=["VHM0","WDIR","WSPD"])
data
# Out:
#            VHM0      WDIR      WSPD
# 0      0.283133       NaN       NaN
# 1      0.337349       NaN       NaN
# 2      0.349398       NaN       NaN
# 3      0.337349       NaN       NaN
# 4      0.337349       NaN       NaN
# ...         ...       ...       ...
# 51139  0.283133  0.800000  0.589354
# 51140  0.259036  0.742857  0.452471
# 51141  0.240964  0.742857  0.471483
# 51142  0.253012  0.714286  0.391635
# 51143       NaN       NaN       NaN
#
# [51144 rows x 3 columns]

# %% [markdown]
# <h2>In our model, we are gonna use the previous values of significant wave height measured to predict the next value</h2>

# %%
#So we are gonna shift the column to add the previous values to the model
data["VHM0 t-1"] = data["VHM0"].shift()
data
# Out:
#            VHM0      WDIR      WSPD  VHM0 t-1
# 0      0.283133       NaN       NaN       NaN
# 1      0.337349       NaN       NaN  0.283133
# 2      0.349398       NaN       NaN  0.337349
# 3      0.337349       NaN       NaN  0.349398
# 4      0.337349       NaN       NaN  0.337349
# ...         ...       ...       ...       ...
# 51139  0.283133  0.800000  0.589354  0.265060
# 51140  0.259036  0.742857  0.452471  0.283133
# 51141  0.240964  0.742857  0.471483  0.259036
# 51142  0.253012  0.714286  0.391635  0.240964
# 51143       NaN       NaN       NaN  0.253012
#
# [51144 rows x 4 columns]

# %% [markdown]
# <h3>The input of the LSTM model must be three dimensionnal, reprsenting respectively:</h3>
#
# 1. the Samples
# 2. the time steps
# 3. Features
#
# <h3>The next function is used to prepare and reshape data to be used in the LSTM model.</h3>

# %%
def data_prep(data, lag, X_col, y_col):
    #data---type: numpy 2d array -----def: is the data used
    #lag---type: int-------def:  represent the the time steps 
    #X_col----type: list,--------def: represente the index of the columns used as input in the model
    #y_col----type: list,--------def: represente the index of the columns used as output in the model
    X_train = []
    y_train = []
    for i in range(lag, int(len(data))):
        X_train.append(data[i-lag:i, X_col])
        y_train.append(data[i-1, y_col])
    X_train, y_train = np.array(X_train), np.array(y_train)

    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], len(X_col)))
    return [X_train, y_train]

# %%
#the time step used is 10 previous hours of data measured
X, y = data_prep(data.to_numpy(), lag=10, X_col=[1,2,3], y_col=[0])

# %%
#Data verification
X[:10]
# Out:
# array([[[       nan,        nan,        nan],
#         [       nan,        nan, 0.28313253],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ]],
#
#        [[       nan,        nan, 0.28313253],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892]],
#
#        [[       nan,        nan, 0.34939759],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072]],
#
#        [[       nan,        nan, 0.3373494 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.29518072]],
#
#        [[       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.27710843]],
#
#        [[       nan,        nan, 0.3253012 ],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.30722892],
#         [       nan,        nan, 0.31325301],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.29518072],
#         [       nan,        nan, 0.27710843],
#         [       nan,        nan, 0.27710843]]])

# %%
#We need to reshape the y array
y = y.reshape(len(y),)
#Data verification
y[:10]
# Out:
# array([0.31325301, 0.30722892, 0.31325301, 0.30722892, 0.31325301,
#        0.29518072, 0.29518072, 0.27710843, 0.27710843, 0.24096386])

# %%
#Data verification
data.head(15)
# Out:
#         VHM0  WDIR  WSPD  VHM0 t-1
# 0   0.283133   NaN   NaN       NaN
# 1   0.337349   NaN   NaN  0.283133
# 2   0.349398   NaN   NaN  0.337349
# 3   0.337349   NaN   NaN  0.349398
# 4   0.337349   NaN   NaN  0.337349
# 5   0.337349   NaN   NaN  0.337349
# 6   0.337349   NaN   NaN  0.337349
# 7   0.313253   NaN   NaN  0.337349
# 8   0.325301   NaN   NaN  0.313253
# 9   0.313253   NaN   NaN  0.325301
# 10  0.307229   NaN   NaN  0.313253
# 11  0.313253   NaN   NaN  0.307229
# 12  0.307229   NaN   NaN  0.313253
# 13  0.313253   NaN   NaN  0.307229
# 14  0.295181   NaN   NaN  0.313253

# %%
#we need to get the corresponding time to plot it in Altair in the next sections
time_model = np.array(time[10:])

# %% [markdown]
# <h3>The Next cell present how to find and delete the nan values in the input and output numpy arrays</h3>

# %%
#Determine where there's a nan value in input or output (if any of [x1, x2, ...] == nan np.isnan == True)
x_nan_index = np.isnan(X).any(axis=1)
x_nan_index = x_nan_index[:,0] | x_nan_index[:,1] |  x_nan_index[:,2]
y_nan_index = np.isnan(y)
#Apply the OR operation on the two index
train_index = x_nan_index | y_nan_index
#Get the values or vectors where's there's no nan values
X = X[~train_index]
y = y[~train_index]
time_model = time_model[~train_index]

# %%
#Now we split the data into train and test datasets, and also split the time array
X_train, X_test, y_train, y_test, time_train, time_test = train_test_split(X, y, time_model, test_size=0.33, random_state=77)

# %% [markdown]
# <h1><center>Modeling using LSTM</center></h1>

# %% [markdown]
# <img src="https://miro.medium.com/max/594/0*dhz-SOm-BW3rTEYa" alt="LSTM model image" title="" />

# %% [markdown]
# <h3> <center>In the next cells, we are gonna create and train out LSTM model and check its performance</center></h3>
# <h4> We would like to point out that the architecture of the model is not optimized, and there's overfitting that can be avoided by analyzing more efficiently the data and maybe split the train, validation, and test datasets manually</h4>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.1'

# %%
#Define the structure of the model
model = Sequential()

model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 3)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 100))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')


history = model.fit(X_train, y_train, epochs =100, batch_size = 1000, validation_split=0.3)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 3s 183ms/step - loss: 0.0163 - val_loss: 0.0078
# Epoch 2/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0054 - val_loss: 0.0028
# Epoch 3/100
# 14/14 [==============================] - 2s 127ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 4/100
# 14/14 [==============================] - 2s 125ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 5/100
# 14/14 [==============================] - 2s 122ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 6/100
# 14/14 [==============================] - 2s 120ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 7/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 8/100
# 14/14 [==============================] - 2s 121ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 9/100
# 14/14 [==============================] - 2s 119ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 10/100
# 14/14 [==============================] - 2s 120ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 11/100
# 14/14 [==============================] - 2s 120ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 12/100
# 14/14 [==============================] - 2s 128ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 13/100
# 14/14 [==============================] - 2s 122ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 14/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 15/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 16/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 17/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 18/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 19/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.0014 - val_loss: 9.7230e-04
# Epoch 20/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.0014 - val_loss: 9.3938e-04
# Epoch 21/100
# 14/14 [==============================] - 2s 128ms/step - loss: 0.0013 - val_loss: 9.2209e-04
# Epoch 22/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0013 - val_loss: 8.8490e-04
# Epoch 23/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.0013 - val_loss: 8.3929e-04
# Epoch 24/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.0012 - val_loss: 8.0576e-04
# Epoch 25/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.0012 - val_loss: 7.8843e-04
# Epoch 26/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.0012 - val_loss: 7.7284e-04
# Epoch 27/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0011 - val_loss: 7.4663e-04
# Epoch 28/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.0011 - val_loss: 7.6802e-04
# Epoch 29/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0011 - val_loss: 7.3006e-04
# Epoch 30/100
# 14/14 [==============================] - 2s 127ms/step - loss: 0.0011 - val_loss: 6.8475e-04
# Epoch 31/100
# 14/14 [==============================] - 2s 127ms/step - loss: 0.0010 - val_loss: 6.6974e-04
# Epoch 32/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0010 - val_loss: 6.7825e-04
# Epoch 33/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0010 - val_loss: 6.5328e-04
# Epoch 34/100
# 14/14 [==============================] - 2s 117ms/step - loss: 9.9593e-04 - val_loss: 6.8553e-04
# Epoch 35/100
# 14/14 [==============================] - 2s 118ms/step - loss: 9.7480e-04 - val_loss: 6.6842e-04
# Epoch 36/100
# 14/14 [==============================] - 2s 117ms/step - loss: 9.4261e-04 - val_loss: 6.1569e-04
# Epoch 37/100
# 14/14 [==============================] - 2s 116ms/step - loss: 9.5382e-04 - val_loss: 6.4160e-04
# Epoch 38/100
# 14/14 [==============================] - 2s 119ms/step - loss: 9.1148e-04 - val_loss: 6.0269e-04
# Epoch 39/100
# 14/14 [==============================] - 2s 127ms/step - loss: 9.1446e-04 - val_loss: 5.9712e-04
# Epoch 40/100
# 14/14 [==============================] - 2s 121ms/step - loss: 9.0373e-04 - val_loss: 6.4978e-04
# Epoch 41/100
# 14/14 [==============================] - 2s 117ms/step - loss: 8.9951e-04 - val_loss: 5.9248e-04
# Epoch 42/100
# 14/14 [==============================] - 2s 118ms/step - loss: 8.6297e-04 - val_loss: 5.8610e-04
# Epoch 43/100
# 14/14 [==============================] - 2s 116ms/step - loss: 8.7122e-04 - val_loss: 6.0834e-04
# Epoch 44/100
# 14/14 [==============================] - 2s 118ms/step - loss: 8.6161e-04 - val_loss: 5.6168e-04
# Epoch 45/100
# 14/14 [==============================] - 2s 116ms/step - loss: 8.4822e-04 - val_loss: 5.5684e-04
# Epoch 46/100
# 14/14 [==============================] - 2s 119ms/step - loss: 8.4861e-04 - val_loss: 5.5727e-04
# Epoch 47/100
# 14/14 [==============================] - 2s 116ms/step - loss: 8.1880e-04 - val_loss: 5.4935e-04
# Epoch 48/100
# 14/14 [==============================] - 2s 126ms/step - loss: 8.2877e-04 - val_loss: 5.4498e-04
# Epoch 49/100
# 14/14 [==============================] - 2s 121ms/step - loss: 8.0736e-04 - val_loss: 5.3756e-04
# Epoch 50/100
# 14/14 [==============================] - 2s 118ms/step - loss: 8.0786e-04 - val_loss: 5.3224e-04
# Epoch 51/100
# 14/14 [==============================] - 2s 118ms/step - loss: 8.1788e-04 - val_loss: 5.5889e-04
# Epoch 52/100
# 14/14 [==============================] - 2s 117ms/step - loss: 8.3192e-04 - val_loss: 5.8500e-04
# Epoch 53/100
# 14/14 [==============================] - 2s 119ms/step - loss: 8.0544e-04 - val_loss: 5.5264e-04
# Epoch 54/100
# 14/14 [==============================] - 2s 117ms/step - loss: 7.9279e-04 - val_loss: 5.1956e-04
# Epoch 55/100
# 14/14 [==============================] - 2s 119ms/step - loss: 7.6219e-04 - val_loss: 5.2669e-04
# Epoch 56/100
# 14/14 [==============================] - 2s 117ms/step - loss: 7.5579e-04 - val_loss: 5.0132e-04
# Epoch 57/100
# 14/14 [==============================] - 2s 126ms/step - loss: 7.3574e-04 - val_loss: 4.9778e-04
# Epoch 58/100
# 14/14 [==============================] - 2s 121ms/step - loss: 7.4711e-04 - val_loss: 5.2304e-04
# Epoch 59/100
# 14/14 [==============================] - 2s 117ms/step - loss: 7.4108e-04 - val_loss: 5.2056e-04
# Epoch 60/100
# 14/14 [==============================] - 2s 116ms/step - loss: 7.5308e-04 - val_loss: 5.2448e-04
# Epoch 61/100
# 14/14 [==============================] - 2s 118ms/step - loss: 7.5301e-04 - val_loss: 5.1009e-04
# Epoch 62/100
# 14/14 [==============================] - 2s 116ms/step - loss: 7.1371e-04 - val_loss: 4.8429e-04
# Epoch 63/100
# 14/14 [==============================] - 2s 118ms/step - loss: 7.3404e-04 - val_loss: 4.7272e-04
# Epoch 64/100
# 14/14 [==============================] - 2s 117ms/step - loss: 7.1279e-04 - val_loss: 4.7274e-04
# Epoch 65/100
# 14/14 [==============================] - 2s 118ms/step - loss: 7.0535e-04 - val_loss: 4.6492e-04
# Epoch 66/100
# 14/14 [==============================] - 2s 125ms/step - loss: 6.8854e-04 - val_loss: 4.6445e-04
# Epoch 67/100
# 14/14 [==============================] - 2s 130ms/step - loss: 7.2795e-04 - val_loss: 5.3256e-04
# Epoch 68/100
# 14/14 [==============================] - 2s 120ms/step - loss: 6.8764e-04 - val_loss: 4.6479e-04
# Epoch 69/100
# 14/14 [==============================] - 2s 119ms/step - loss: 6.9015e-04 - val_loss: 4.7740e-04
# Epoch 70/100
# 14/14 [==============================] - 2s 117ms/step - loss: 6.7406e-04 - val_loss: 4.8251e-04
# Epoch 71/100
# 14/14 [==============================] - 2s 117ms/step - loss: 6.7835e-04 - val_loss: 4.6624e-04
# Epoch 72/100
# 14/14 [==============================] - 2s 119ms/step - loss: 6.6461e-04 - val_loss: 4.5436e-04
# Epoch 73/100
# 14/14 [==============================] - 2s 117ms/step - loss: 6.5602e-04 - val_loss: 4.5523e-04
# Epoch 74/100
# 14/14 [==============================] - 2s 118ms/step - loss: 6.5168e-04 - val_loss: 4.4818e-04
# Epoch 75/100
# 14/14 [==============================] - 2s 126ms/step - loss: 6.4917e-04 - val_loss: 4.4215e-04
# Epoch 76/100
# 14/14 [==============================] - 2s 122ms/step - loss: 6.6591e-04 - val_loss: 4.6407e-04
# Epoch 77/100
# 14/14 [==============================] - 2s 119ms/step - loss: 6.5579e-04 - val_loss: 4.6820e-04
# Epoch 78/100
# 14/14 [==============================] - 2s 128ms/step - loss: 6.6418e-04 - val_loss: 4.8882e-04
# Epoch 79/100
# 14/14 [==============================] - 2s 132ms/step - loss: 6.5628e-04 - val_loss: 4.5060e-04
# Epoch 80/100
# 14/14 [==============================] - 2s 122ms/step - loss: 6.4534e-04 - val_loss: 4.4084e-04
# Epoch 81/100
# 14/14 [==============================] - 2s 118ms/step - loss: 6.3446e-04 - val_loss: 4.2969e-04
# Epoch 82/100
# 14/14 [==============================] - 2s 117ms/step - loss: 6.3519e-04 - val_loss: 4.2791e-04
# Epoch 83/100
# 14/14 [==============================] - 2s 121ms/step - loss: 6.1320e-04 - val_loss: 4.3075e-04
# Epoch 84/100
# 14/14 [==============================] - 2s 132ms/step - loss: 6.0860e-04 - val_loss: 4.3679e-04
# Epoch 85/100
# 14/14 [==============================] - 2s 118ms/step - loss: 6.3472e-04 - val_loss: 4.2394e-04
# Epoch 86/100
# 14/14 [==============================] - 2s 120ms/step - loss: 6.3430e-04 - val_loss: 4.5896e-04
# Epoch 87/100
# 14/14 [==============================] - 2s 120ms/step - loss: 6.2195e-04 - val_loss: 4.3418e-04
# Epoch 88/100
# 14/14 [==============================] - 2s 124ms/step - loss: 6.0272e-04 - val_loss: 4.3012e-04
# Epoch 89/100
# 14/14 [==============================] - 2s 117ms/step - loss: 6.0313e-04 - val_loss: 4.2887e-04
# Epoch 90/100
# 14/14 [==============================] - 2s 118ms/step - loss: 6.0992e-04 - val_loss: 4.2044e-04
# Epoch 91/100
# 14/14 [==============================] - 2s 117ms/step - loss: 6.0363e-04 - val_loss: 4.3496e-04
# Epoch 92/100
# 14/14 [==============================] - 2s 119ms/step - loss: 6.2606e-04 - val_loss: 4.2103e-04
# Epoch 93/100
# 14/14 [==============================] - 2s 130ms/step - loss: 6.1184e-04 - val_loss: 4.3464e-04
# Epoch 94/100
# 14/14 [==============================] - 2s 118ms/step - loss: 6.0747e-04 - val_loss: 4.1986e-04
# Epoch 95/100
# 14/14 [==============================] - 2s 117ms/step - loss: 5.8719e-04 - val_loss: 4.1619e-04
# Epoch 96/100
# 14/14 [==============================] - 2s 118ms/step - loss: 5.9265e-04 - val_loss: 4.1683e-04
# Epoch 97/100
# 14/14 [==============================] - 2s 117ms/step - loss: 5.9120e-04 - val_loss: 4.3611e-04
# Epoch 98/100
# 14/14 [==============================] - 2s 124ms/step - loss: 5.8866e-04 - val_loss: 4.1143e-04
# Epoch 99/100
# 14/14 [==============================] - 2s 124ms/step - loss: 5.9487e-04 - val_loss: 4.1182e-04
# Epoch 100/100
# 14/14 [==============================] - 2s 119ms/step - loss: 5.8197e-04 - val_loss: 4.1079e-04

# %%
#checking the performance of the model on the training period
preds = model.predict(X_train)
rmse = np.sqrt(mean_squared_error(y_train, preds))
r2 = r2_score(y_train, preds)
print('results for calibration \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for calibration
#
# RMSE: 0.020757
# R²: 0.963126

# %%
#checking the performance of the model on the testing period
preds_test = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds_test))
r2 = r2_score(y_test, preds_test)
print('results for testing \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for testing
#
# RMSE: 0.020009
# R²: 0.965321

# %% [markdown]
# <h3> We can see that the model have a great performance</h3>

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# <h2><center> Training Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the training period
train_to_plot = pd.DataFrame({"y_true": y_train,
                 "y_pred" : preds.reshape(len(preds)),
                 "date" : time_train})
train_to_plot
# Out:
#          y_true    y_pred                date
# 0      0.162651  0.173500 2019-10-12 10:00:00
# 1      0.126506  0.136271 2019-09-20 06:00:00
# 2      0.054217  0.055553 2019-07-20 04:00:00
# 3      0.084337  0.079843 2017-08-15 00:00:00
# 4      0.096386  0.098471 2017-09-21 16:00:00
# ...         ...       ...                 ...
# 19867  0.042169  0.041000 2019-07-12 02:00:00
# 19868  0.054217  0.050164 2020-06-18 12:00:00
# 19869  0.090361  0.093476 2020-08-28 19:00:00
# 19870  0.403614  0.416405 2018-01-03 20:00:00
# 19871  0.240964  0.230197 2019-01-14 15:00:00
#
# [19872 rows x 3 columns]

# %%
#Q-Q plot of the training period
train_to_plot.plot.scatter(x="y_pred", y="y_true", figsize=(8,8))
plt.title('Q-Q plot of the LSTM model (training period)"')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'Q-Q plot of the LSTM model (training period)"')

# %% [markdown]
# <h3>We can observe that some values were not predicted very well, we recommend the potential users to check the data</h3>

# %%
#Plotting the evolution of predicted and observed values over time for the traiing period
plt.figure(figsize=(18,6))
sns.scatterplot(data=pd.melt(train_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), x="date", y="value", hue="categorie")
plt.title("Evolution of the predicted and the observed values(training period)")
# Out:
# Text(0.5, 1.0, 'Evolution of the predicted and the observed values(training period)')

# %% [markdown]
# <h2><center> Testing Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the testing period
test_to_plot = pd.DataFrame({"y_true": y_test,
                 "y_pred" : preds_test.reshape(len(preds_test)),
                 "date" : time_test})
test_to_plot
# Out:
#         y_true    y_pred                date
# 0     0.126506  0.120257 2020-05-29 17:00:00
# 1     0.180723  0.174715 2019-04-29 14:00:00
# 2     0.228916  0.254177 2016-11-09 12:00:00
# 3     0.156627  0.176390 2018-05-13 11:00:00
# 4     0.198795  0.219840 2019-01-31 01:00:00
# ...        ...       ...                 ...
# 9783  0.090361  0.079026 2020-05-31 07:00:00
# 9784  0.162651  0.159733 2019-10-19 20:00:00
# 9785  0.198795  0.220944 2016-09-21 06:00:00
# 9786  0.222892  0.228490 2018-12-17 12:00:00
# 9787  0.072289  0.072113 2016-05-23 17:00:00
#
# [9788 rows x 3 columns]

# %%
#Q-Q plot of the testing period
test_to_plot.plot.scatter(x="y_pred", y="y_true", figsize=(8,8))
plt.title('Q-Q plot of the LSTM model (testing period)"')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'Q-Q plot of the LSTM model (testing period)"')

# %%
#Plotting the evolution of predicted and observed values over time for the traiing period
plt.figure(figsize=(18,6))
sns.scatterplot(data=pd.melt(test_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), x="date", y="value", hue="categorie")
plt.title("Evolution of the predicted and the observed values(testing period)")
# Out:
# Text(0.5, 1.0, 'Evolution of the predicted and the observed values(testing period)')

# %% [markdown]
# <h1><center>Modeling using CNN</center></h1>

# %% [markdown]
# <img src="https://www.aimspress.com/aimspress-data/mbe/2021/1/PIC/mbe-18-01-022-g004.jpg" alt="CNN for time series image" title="" />

# %% [markdown]
# <h3> <center>In the next cells, we are gonna create and train our CNN model and check its performance</center></h3>
# <h4> We would like to point out that the architecture of the model is not optimized, and there's overfitting that can be avoided by analyzing more efficiently the data and maybe split the train, validation, and test datasets manually</h4>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import tensorflow as tf

# %%
#Define the structure of the model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation=tf.keras.layers.LeakyReLU(alpha=0.3), input_shape=(X_test.shape[1], 3)))
model.add(MaxPooling1D(pool_size=2, padding='SAME'))

model.add(Flatten())

model.add(Dense(100, activation='elu'))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

history = model.fit(X_train, y_train, epochs = 150, batch_size = 1000, validation_split=0.3)
# Out:
# Epoch 1/150
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0147 - val_loss: 0.0023
# Epoch 2/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0019
# Epoch 3/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 4/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 9.2417e-04
# Epoch 5/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 8.2169e-04
# Epoch 6/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 7.5973e-04
# Epoch 7/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 7.1752e-04
# Epoch 8/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 6.7679e-04
# Epoch 9/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 6.4020e-04
# Epoch 10/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 6.1771e-04
# Epoch 11/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 5.8835e-04
# Epoch 12/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 5.9981e-04
# Epoch 13/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 5.6566e-04
# Epoch 14/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 5.2438e-04
# Epoch 15/150
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 5.1828e-04
# Epoch 16/150
# 14/14 [==============================] - 0s 5ms/step - loss: 9.9186e-04 - val_loss: 5.1954e-04
# Epoch 17/150
# 14/14 [==============================] - 0s 5ms/step - loss: 9.5276e-04 - val_loss: 4.8946e-04
# Epoch 18/150
# 14/14 [==============================] - 0s 5ms/step - loss: 9.3606e-04 - val_loss: 4.8137e-04
# Epoch 19/150
# 14/14 [==============================] - 0s 5ms/step - loss: 9.1935e-04 - val_loss: 4.7417e-04
# Epoch 20/150
# 14/14 [==============================] - 0s 5ms/step - loss: 9.0312e-04 - val_loss: 4.7203e-04
# Epoch 21/150
# 14/14 [==============================] - 0s 5ms/step - loss: 9.0847e-04 - val_loss: 4.6942e-04
# Epoch 22/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.6461e-04 - val_loss: 4.7386e-04
# Epoch 23/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.4326e-04 - val_loss: 4.6554e-04
# Epoch 24/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.4711e-04 - val_loss: 4.5240e-04
# Epoch 25/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.3281e-04 - val_loss: 4.5069e-04
# Epoch 26/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.0764e-04 - val_loss: 4.6099e-04
# Epoch 27/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.1461e-04 - val_loss: 4.7017e-04
# Epoch 28/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.0099e-04 - val_loss: 4.5907e-04
# Epoch 29/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.0882e-04 - val_loss: 4.7239e-04
# Epoch 30/150
# 14/14 [==============================] - 0s 5ms/step - loss: 8.4153e-04 - val_loss: 4.5138e-04
# Epoch 31/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.7930e-04 - val_loss: 4.3940e-04
# Epoch 32/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.4946e-04 - val_loss: 4.3672e-04
# Epoch 33/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.5495e-04 - val_loss: 4.3507e-04
# Epoch 34/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.6405e-04 - val_loss: 4.3382e-04
# Epoch 35/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.4130e-04 - val_loss: 4.3628e-04
# Epoch 36/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.4100e-04 - val_loss: 4.3856e-04
# Epoch 37/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.4738e-04 - val_loss: 4.3640e-04
# Epoch 38/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.2373e-04 - val_loss: 4.4115e-04
# Epoch 39/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.3940e-04 - val_loss: 4.6808e-04
# Epoch 40/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.1244e-04 - val_loss: 4.3676e-04
# Epoch 41/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.2623e-04 - val_loss: 4.6229e-04
# Epoch 42/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.3028e-04 - val_loss: 4.3147e-04
# Epoch 43/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.2246e-04 - val_loss: 4.3325e-04
# Epoch 44/150
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0283e-04 - val_loss: 4.2210e-04
# Epoch 45/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8615e-04 - val_loss: 4.2443e-04
# Epoch 46/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8043e-04 - val_loss: 4.3456e-04
# Epoch 47/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8277e-04 - val_loss: 4.2026e-04
# Epoch 48/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.7786e-04 - val_loss: 4.2038e-04
# Epoch 49/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.6633e-04 - val_loss: 4.4565e-04
# Epoch 50/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.6132e-04 - val_loss: 4.1712e-04
# Epoch 51/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.7633e-04 - val_loss: 4.3378e-04
# Epoch 52/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.6200e-04 - val_loss: 4.2229e-04
# Epoch 53/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.6702e-04 - val_loss: 4.1752e-04
# Epoch 54/150
# 14/14 [==============================] - 0s 4ms/step - loss: 6.5149e-04 - val_loss: 4.2897e-04
# Epoch 55/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.3818e-04 - val_loss: 4.1788e-04
# Epoch 56/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.5907e-04 - val_loss: 4.1308e-04
# Epoch 57/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.3860e-04 - val_loss: 4.1877e-04
# Epoch 58/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.4719e-04 - val_loss: 4.2857e-04
# Epoch 59/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.3181e-04 - val_loss: 4.1264e-04
# Epoch 60/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.2959e-04 - val_loss: 4.1382e-04
# Epoch 61/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.2982e-04 - val_loss: 4.1018e-04
# Epoch 62/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.2562e-04 - val_loss: 4.2710e-04
# Epoch 63/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.3064e-04 - val_loss: 4.1940e-04
# Epoch 64/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.3436e-04 - val_loss: 4.1182e-04
# Epoch 65/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.2116e-04 - val_loss: 4.0907e-04
# Epoch 66/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.1825e-04 - val_loss: 4.1374e-04
# Epoch 67/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.3142e-04 - val_loss: 4.1799e-04
# Epoch 68/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.2159e-04 - val_loss: 4.1294e-04
# Epoch 69/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.1322e-04 - val_loss: 4.0756e-04
# Epoch 70/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.1245e-04 - val_loss: 4.0924e-04
# Epoch 71/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.0815e-04 - val_loss: 4.0641e-04
# Epoch 72/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.1721e-04 - val_loss: 4.1913e-04
# Epoch 73/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.1577e-04 - val_loss: 4.0505e-04
# Epoch 74/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.0143e-04 - val_loss: 4.0562e-04
# Epoch 75/150
# 14/14 [==============================] - 0s 5ms/step - loss: 6.0652e-04 - val_loss: 4.1312e-04
# Epoch 76/150
# 14/14 [==============================] - 0s 4ms/step - loss: 5.9386e-04 - val_loss: 4.0647e-04
# Epoch 77/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.9324e-04 - val_loss: 4.1163e-04
# Epoch 78/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.8784e-04 - val_loss: 4.2925e-04
# Epoch 79/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.8586e-04 - val_loss: 4.0621e-04
# Epoch 80/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.9105e-04 - val_loss: 4.1674e-04
# Epoch 81/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.7394e-04 - val_loss: 4.0740e-04
# Epoch 82/150
# 14/14 [==============================] - 0s 4ms/step - loss: 5.7673e-04 - val_loss: 4.0278e-04
# Epoch 83/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.7008e-04 - val_loss: 4.2035e-04
# Epoch 84/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.9228e-04 - val_loss: 4.1696e-04
# Epoch 85/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.8658e-04 - val_loss: 4.1148e-04
# Epoch 86/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5725e-04 - val_loss: 4.0955e-04
# Epoch 87/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.7632e-04 - val_loss: 4.0474e-04
# Epoch 88/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.6833e-04 - val_loss: 4.1018e-04
# Epoch 89/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.6328e-04 - val_loss: 4.0306e-04
# Epoch 90/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5301e-04 - val_loss: 4.0551e-04
# Epoch 91/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.6755e-04 - val_loss: 4.0365e-04
# Epoch 92/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.6476e-04 - val_loss: 4.1907e-04
# Epoch 93/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5045e-04 - val_loss: 4.0007e-04
# Epoch 94/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.6724e-04 - val_loss: 4.0341e-04
# Epoch 95/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.7016e-04 - val_loss: 4.1808e-04
# Epoch 96/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5730e-04 - val_loss: 3.9846e-04
# Epoch 97/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5654e-04 - val_loss: 4.0168e-04
# Epoch 98/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.6780e-04 - val_loss: 4.2324e-04
# Epoch 99/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.6389e-04 - val_loss: 4.1827e-04
# Epoch 100/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5941e-04 - val_loss: 4.0211e-04
# Epoch 101/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4146e-04 - val_loss: 3.9598e-04
# Epoch 102/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5581e-04 - val_loss: 3.9983e-04
# Epoch 103/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4000e-04 - val_loss: 3.9933e-04
# Epoch 104/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4195e-04 - val_loss: 3.9695e-04
# Epoch 105/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4465e-04 - val_loss: 4.2721e-04
# Epoch 106/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4109e-04 - val_loss: 4.0322e-04
# Epoch 107/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4330e-04 - val_loss: 3.9826e-04
# Epoch 108/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3907e-04 - val_loss: 3.9791e-04
# Epoch 109/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4533e-04 - val_loss: 4.3367e-04
# Epoch 110/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3156e-04 - val_loss: 4.0339e-04
# Epoch 111/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3730e-04 - val_loss: 4.2227e-04
# Epoch 112/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3072e-04 - val_loss: 4.0243e-04
# Epoch 113/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4808e-04 - val_loss: 3.9523e-04
# Epoch 114/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3915e-04 - val_loss: 3.9571e-04
# Epoch 115/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2740e-04 - val_loss: 3.9184e-04
# Epoch 116/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3126e-04 - val_loss: 4.0311e-04
# Epoch 117/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3432e-04 - val_loss: 3.9574e-04
# Epoch 118/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3287e-04 - val_loss: 3.9471e-04
# Epoch 119/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3363e-04 - val_loss: 3.9151e-04
# Epoch 120/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2574e-04 - val_loss: 3.9162e-04
# Epoch 121/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2624e-04 - val_loss: 4.3241e-04
# Epoch 122/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.3980e-04 - val_loss: 4.5749e-04
# Epoch 123/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.4543e-04 - val_loss: 4.1066e-04
# Epoch 124/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2057e-04 - val_loss: 3.9222e-04
# Epoch 125/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1690e-04 - val_loss: 3.9583e-04
# Epoch 126/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1968e-04 - val_loss: 3.9045e-04
# Epoch 127/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2413e-04 - val_loss: 3.9147e-04
# Epoch 128/150
# 14/14 [==============================] - 0s 6ms/step - loss: 5.1067e-04 - val_loss: 3.9270e-04
# Epoch 129/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1119e-04 - val_loss: 3.9239e-04
# Epoch 130/150
# 14/14 [==============================] - 0s 6ms/step - loss: 5.2616e-04 - val_loss: 4.0263e-04
# Epoch 131/150
# 14/14 [==============================] - 0s 6ms/step - loss: 5.1013e-04 - val_loss: 3.9279e-04
# Epoch 132/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0936e-04 - val_loss: 4.4420e-04
# Epoch 133/150
# 14/14 [==============================] - 0s 6ms/step - loss: 5.3744e-04 - val_loss: 4.6241e-04
# Epoch 134/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2092e-04 - val_loss: 3.8846e-04
# Epoch 135/150
# 14/14 [==============================] - 0s 6ms/step - loss: 5.1222e-04 - val_loss: 4.0042e-04
# Epoch 136/150
# 14/14 [==============================] - 0s 6ms/step - loss: 5.0375e-04 - val_loss: 3.8878e-04
# Epoch 137/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0953e-04 - val_loss: 3.9449e-04
# Epoch 138/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0855e-04 - val_loss: 4.6082e-04
# Epoch 139/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.2240e-04 - val_loss: 3.9256e-04
# Epoch 140/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0369e-04 - val_loss: 3.8973e-04
# Epoch 141/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.8719e-04 - val_loss: 3.9097e-04
# Epoch 142/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0461e-04 - val_loss: 3.9186e-04
# Epoch 143/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0093e-04 - val_loss: 4.0123e-04
# Epoch 144/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.1261e-04 - val_loss: 3.9193e-04
# Epoch 145/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0209e-04 - val_loss: 3.9717e-04
# Epoch 146/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.8828e-04 - val_loss: 3.8668e-04
# Epoch 147/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.7983e-04 - val_loss: 3.9046e-04
# Epoch 148/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.9746e-04 - val_loss: 3.8951e-04
# Epoch 149/150
# 14/14 [==============================] - 0s 5ms/step - loss: 4.9087e-04 - val_loss: 4.0734e-04
# Epoch 150/150
# 14/14 [==============================] - 0s 5ms/step - loss: 5.0266e-04 - val_loss: 3.8694e-04

# %%
#checking the performance of the model on the training period
preds = model.predict(X_train)
rmse = np.sqrt(mean_squared_error(y_train, preds))
r2 = r2_score(y_train, preds)
print('results for calibration \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for calibration
#
# RMSE: 0.020029
# R²: 0.965670

# %%
#checking the performance of the model on the testing period
preds_test = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds_test))
r2 = r2_score(y_test, preds_test)
print('results for testing \n')
print("RMSE: %f" % (rmse))
print("R²: %f" % (r2))
# Out:
# results for testing
#
# RMSE: 0.019380
# R²: 0.967466

# %% [markdown]
# <h3> We can see that the model have a great performance</h3>
# <h3>We recommend the potential users to use the CNN instead of LSTM if the performance is the same due to the less computation time</h3>

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# <h2><center> Training Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the training period
train_to_plot = pd.DataFrame({"y_true": y_train,
                 "y_pred" : preds.reshape(len(preds)),
                 "date" : time_train})
train_to_plot
# Out:
#          y_true    y_pred                date
# 0      0.162651  0.168431 2019-10-12 10:00:00
# 1      0.126506  0.142239 2019-09-20 06:00:00
# 2      0.054217  0.051510 2019-07-20 04:00:00
# 3      0.084337  0.091105 2017-08-15 00:00:00
# 4      0.096386  0.096897 2017-09-21 16:00:00
# ...         ...       ...                 ...
# 19867  0.042169  0.047188 2019-07-12 02:00:00
# 19868  0.054217  0.052159 2020-06-18 12:00:00
# 19869  0.090361  0.101037 2020-08-28 19:00:00
# 19870  0.403614  0.401095 2018-01-03 20:00:00
# 19871  0.240964  0.216392 2019-01-14 15:00:00
#
# [19872 rows x 3 columns]

# %%
#Q-Q plot of the training period
train_to_plot.plot.scatter(x="y_pred", y="y_true", figsize=(8,8))
plt.title('Q-Q plot of the LSTM model (training period)"')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'Q-Q plot of the LSTM model (training period)"')

# %% [markdown]
# <h3> We can observe that there are also (maybe the same observations as in the LSTM section) some values that were not predicted very well, we recommend the potential users to check the data</h3>

# %%
#Plotting the evolution of predicted and observed values over time for the traiing period
plt.figure(figsize=(18,6))
sns.scatterplot(data=pd.melt(train_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), x="date", y="value", hue="categorie")
plt.title("Evolution of the predicted and the observed values(training period)")
# Out:
# Text(0.5, 1.0, 'Evolution of the predicted and the observed values(training period)')

# %% [markdown]
# <h2><center> Testing Part</center></h2>

# %%
#We create a dataframe in order to plot the evolution of the predicted and the observed values of the testing period
test_to_plot = pd.DataFrame({"y_true": y_test,
                 "y_pred" : preds_test.reshape(len(preds_test)),
                 "date" : time_test})
test_to_plot
# Out:
#         y_true    y_pred                date
# 0     0.126506  0.119907 2020-05-29 17:00:00
# 1     0.180723  0.171844 2019-04-29 14:00:00
# 2     0.228916  0.257689 2016-11-09 12:00:00
# 3     0.156627  0.168052 2018-05-13 11:00:00
# 4     0.198795  0.201464 2019-01-31 01:00:00
# ...        ...       ...                 ...
# 9783  0.090361  0.085019 2020-05-31 07:00:00
# 9784  0.162651  0.160311 2019-10-19 20:00:00
# 9785  0.198795  0.213840 2016-09-21 06:00:00
# 9786  0.222892  0.240133 2018-12-17 12:00:00
# 9787  0.072289  0.071828 2016-05-23 17:00:00
#
# [9788 rows x 3 columns]

# %%
#Q-Q plot of the testing period
test_to_plot.plot.scatter(x="y_pred", y="y_true", figsize=(8,8))
plt.title('Q-Q plot of the LSTM model (testing period)"')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'Q-Q plot of the LSTM model (testing period)"')

# %%
#Plotting the evolution of predicted and observed values over time for the testing period
plt.figure(figsize=(18,6))
sns.scatterplot(data=pd.melt(test_to_plot, id_vars=['date'], value_vars=["y_true","y_pred"],
        var_name='categorie', value_name='value'), x="date", y="value", hue="categorie")
plt.title("Evolution of the predicted and the observed values(testing period)")
# Out:
# Text(0.5, 1.0, 'Evolution of the predicted and the observed values(testing period)')
